# %% [markdown]
# <a href="https://colab.research.google.com/github/dannyRT21/ConversorProgra2/blob/main/introducion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre = "Luis"
edad = "32"

Print(nombre,edad)

eDad = "cinco"
Print("tu edad: ", eDad)

# %%
num1 = 5.3
num2 = 5.7
suma = num1 + num2
print("la suma es: suma: ", suma)
# Out:
# la suma es: suma:  11.0

# %%
num1 = float(input("Num1: "))
num2 = float(input("Num2: "))
suma = num1 + num2
print("la suma es: suma: ", suma)
# Out:
# Num1: 2
# Num2: 9
# la suma es: suma:  11.0

# %%
num1 = float(input("Num1: "))
num2 = float(input("Num2: "))
resta = num1 - num2
print("la resta es ", resta)
# Out:
# Num1: 2
# Num2: 5
# la resta es  -3.0
